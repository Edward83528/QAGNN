# %%
print("start")

# %% [markdown]
# ### google.colab 掛載雲端硬碟(google.colab才需要執行)

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !ls 'drive'

# %%
# import os
# path = "/content/drive/My Drive/Colab Notebooks/qagnn/reference/"
# os.chdir(path)

# %%
# !ls
# Out:
#  LICENSE
# 'QA-GNN Reasoning with Language Models and Knowledge Graphs for Question Answering.pdf'
#  README.md
#  data
#  data_preprocessed_release.zip
#  download_preprocessed_data.sh
#  download_raw_data.sh
#  figs
#  modeling
#  preprocess.py
#  qagnn.py
#  run_qagnn__csqa.sh
#  run_qagnn__obqa.sh
#  saved_models
#  train.ipynb
#  train_csqa__enc-roberta-large__k5__gnndim200__bs128__seed0__20211009_132528.log.txt
#  utils
#  wgetDataPreprocessed.ipynb

# %% [markdown]
# ## 安裝套件與環境

# %%
#conda install pytorch==1.4.0 torchvision==0.5.0 cudatoolkit=10.1 -c pytorch
# !pip install torch==1.4.0 torchvision==0.5.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch==1.4.0 in /user_data/.local/lib/python3.6/site-packages (1.4.0)
# Requirement already satisfied: torchvision==0.5.0 in /user_data/.local/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.5.0) (1.15.0)
# Requirement already satisfied: numpy in /user_data/.local/lib/python3.6/site-packages (from torchvision==0.5.0) (1.18.3)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import torch

# %%
print(torch.__version__)
# Out:
# 1.4.0

# %%
print(torch.version.cuda)
# Out:
# 10.1

# %%
# !pip install numpy==1.18.3 tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy==1.18.3 in /user_data/.local/lib/python3.6/site-packages (1.18.3)
# Requirement already satisfied: tqdm in /user_data/.local/lib/python3.6/site-packages (4.60.0)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install transformers==2.0.0 nltk spacy==2.1.6
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers==2.0.0 in /user_data/.local/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: nltk in /user_data/.local/lib/python3.6/site-packages (3.6.3)
# Requirement already satisfied: spacy==2.1.6 in /user_data/.local/lib/python3.6/site-packages (2.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==2.0.0) (2.25.0)
# Requirement already satisfied: numpy in /user_data/.local/lib/python3.6/site-packages (from transformers==2.0.0) (1.18.3)
# Requirement already satisfied: regex in /user_data/.local/lib/python3.6/site-packages (from transformers==2.0.0) (2021.4.4)
# Requirement already satisfied: sentencepiece in /user_data/.local/lib/python3.6/site-packages (from transformers==2.0.0) (0.1.95)
# Requirement already satisfied: sacremoses in /user_data/.local/lib/python3.6/site-packages (from transformers==2.0.0) (0.0.45)
# Requirement already satisfied: tqdm in /user_data/.local/lib/python3.6/site-packages (from transformers==2.0.0) (4.60.0)
# Requirement already satisfied: boto3 in /user_data/.local/lib/python3.6/site-packages (from transformers==2.0.0) (1.18.58)
# Requirement already satisfied: click in /user_data/.local/lib/python3.6/site-packages (from nltk) (8.0.0)
# Requirement already satisfied: joblib in /user_data/.local/lib/python3.6/site-packages (from nltk) (1.0.1)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /user_data/.local/lib/python3.6/site-packages (from spacy==2.1.6) (0.2.4)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /user_data/.local/lib/python3.6/site-packages (from spacy==2.1.6) (2.0.1)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /user_data/.local/lib/python3.6/site-packages (from spacy==2.1.6) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /user_data/.local/lib/python3.6/site-packages (from spacy==2.1.6) (0.8.2)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /user_data/.local/lib/python3.6/site-packages (from spacy==2.1.6) (0.9.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /user_data/.local/lib/python3.6/site-packages (from spacy==2.1.6) (2.0.5)
# Requirement already satisfied: thinc<7.1.0,>=7.0.8 in /user_data/.local/lib/python3.6/site-packages (from spacy==2.1.6) (7.0.8)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /user_data/.local/lib/python3.6/site-packages (from spacy==2.1.6) (1.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.0.0) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.0.0) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests->transformers==2.0.0) (2.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==2.0.0) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==2.0.0) (1.15.0)
# Requirement already satisfied: botocore<1.22.0,>=1.21.58 in /user_data/.local/lib/python3.6/site-packages (from boto3->transformers==2.0.0) (1.21.58)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /user_data/.local/lib/python3.6/site-packages (from boto3->transformers==2.0.0) (0.10.0)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /user_data/.local/lib/python3.6/site-packages (from boto3->transformers==2.0.0) (0.5.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.22.0,>=1.21.58->boto3->transformers==2.0.0) (2.8.1)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !python -m spacy download en
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /user_data/.local/lib/python3.6/site-packages (2.1.0)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/bin/python -m pip install --upgrade pip' command.
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# [+] Linking successful
# /user_data/.local/lib/python3.6/site-packages/en_core_web_sm -->
# /user_data/.local/lib/python3.6/site-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# !pip install torch-scatter==2.0.4 -f https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Requirement already satisfied: torch-scatter==2.0.4 in /user_data/.local/lib/python3.6/site-packages (2.0.4)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install torch-cluster==1.5.4 -f https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Requirement already satisfied: torch-cluster==1.5.4 in /user_data/.local/lib/python3.6/site-packages (1.5.4)
# Requirement already satisfied: scipy in /user_data/.local/lib/python3.6/site-packages (from torch-cluster==1.5.4) (1.5.4)
# Requirement already satisfied: numpy>=1.14.5 in /user_data/.local/lib/python3.6/site-packages (from scipy->torch-cluster==1.5.4) (1.18.3)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install torch-sparse==0.6.1 -f https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Requirement already satisfied: torch-sparse==0.6.1 in /user_data/.local/lib/python3.6/site-packages (0.6.1)
# Requirement already satisfied: scipy in /user_data/.local/lib/python3.6/site-packages (from torch-sparse==0.6.1) (1.5.4)
# Requirement already satisfied: numpy>=1.14.5 in /user_data/.local/lib/python3.6/site-packages (from scipy->torch-sparse==0.6.1) (1.18.3)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install torch-spline-conv==1.2.0 -f https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Requirement already satisfied: torch-spline-conv==1.2.0 in /user_data/.local/lib/python3.6/site-packages (1.2.0)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# !pip install torch-geometric==1.6.0 -f https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: https://pytorch-geometric.com/whl/torch-1.4.0+cu101.html
# Requirement already satisfied: torch-geometric==1.6.0 in /user_data/.local/lib/python3.6/site-packages (1.6.0)
# Requirement already satisfied: googledrivedownloader in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from torch-geometric==1.6.0) (2.11.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from torch-geometric==1.6.0) (2.10.0)
# Requirement already satisfied: scikit-learn in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (0.24.2)
# Requirement already satisfied: scipy in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (1.5.4)
# Requirement already satisfied: numpy in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (1.18.3)
# Requirement already satisfied: tqdm in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (4.60.0)
# Requirement already satisfied: networkx in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (2.5.1)
# Requirement already satisfied: numba in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (0.53.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torch-geometric==1.6.0) (2.25.0)
# Requirement already satisfied: torch in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (1.4.0)
# Requirement already satisfied: rdflib in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (5.0.0)
# Requirement already satisfied: pandas in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (1.1.5)
# Requirement already satisfied: ase in /user_data/.local/lib/python3.6/site-packages (from torch-geometric==1.6.0) (3.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->torch-geometric==1.6.0) (1.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->torch-geometric==1.6.0) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /user_data/.local/lib/python3.6/site-packages (from scikit-learn->torch-geometric==1.6.0) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /user_data/.local/lib/python3.6/site-packages (from scikit-learn->torch-geometric==1.6.0) (3.0.0)
# Requirement already satisfied: decorator<5,>=4.3 in /usr/local/lib/python3.6/dist-packages (from networkx->torch-geometric==1.6.0) (4.4.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from numba->torch-geometric==1.6.0) (51.0.0)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /user_data/.local/lib/python3.6/site-packages (from numba->torch-geometric==1.6.0) (0.36.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests->torch-geometric==1.6.0) (2.6)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric==1.6.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric==1.6.0) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torch-geometric==1.6.0) (1.26.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from rdflib->torch-geometric==1.6.0) (2.4.7)
# Requirement already satisfied: isodate in /user_data/.local/lib/python3.6/site-packages (from rdflib->torch-geometric==1.6.0) (0.6.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->torch-geometric==1.6.0) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /user_data/.local/lib/python3.6/site-packages (from pandas->torch-geometric==1.6.0) (2021.1)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.6/dist-packages (from ase->torch-geometric==1.6.0) (3.3.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.1.0->ase->torch-geometric==1.6.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.1.0->ase->torch-geometric==1.6.0) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.1.0->ase->torch-geometric==1.6.0) (8.0.1)
# WARNING: You are using pip version 20.2.4; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ## 執行訓練

# %%
# anaconda用%%shell跑shell
#%%shell
# 實驗室環境用%%bash跑shell
#%%bash

# %%
# %%bash
#
# export PYTHONIOENCODING=utf-8
# export CUDA_VISIBLE_DEVICES=0,1
# dt=`date '+%Y%m%d_%H%M%S'`
#
# mode="eval_detail"
#
# dataset="csqa"
# model='roberta-large'
# shift
# shift
# args=$@
#
#
# elr="1e-5"
# dlr="1e-3"
# bs=128
# n_epochs=20
#
# k=5 #num of gnn layers
# gnndim=200
#
# echo "***** hyperparameters *****"
# echo "dataset: $dataset"
# echo "enc_name: $model"
# echo "batch_size: $bs"
# echo "learning_rate: elr $elr dlr $dlr"
# echo "gnn: dim $gnndim layer $k"
# echo "******************************"
#
# save_dir_pref='saved_models'
# mkdir -p $save_dir_pref
#
# ###### Training ######
# for seed in 0; do
#   python3 -u qagnn.py --dataset $dataset \
#       --encoder $model -k $k --gnn_dim $gnndim -elr $elr -dlr $dlr -bs $bs --seed $seed \
#       --n_epochs $n_epochs --max_epochs_before_stop 10  \
#       --train_adj data/${dataset}/graph/train.graph.adj.pk \
#       --dev_adj   data/${dataset}/graph/dev.graph.adj.pk \
#       --test_adj  data/${dataset}/graph/test.graph.adj.pk \
#       --train_statements  data/${dataset}/statement/train.statement.jsonl \
#       --dev_statements  data/${dataset}/statement/dev.statement.jsonl \
#       --test_statements  data/${dataset}/statement/test.statement.jsonl \
#       --save_model \
#       --save_dir ${save_dir_pref}/${dataset}/enc-${model}__k${k}__gnndim${gnndim}__bs${bs}__seed${seed}__${dt} $args \
#       --load_model_path
#   > train_${dataset}__enc-${model}__k${k}__gnndim${gnndim}__bs${bs}__seed${seed}__${dt}.log.txt
# done
# Out:
# ***** hyperparameters *****
# dataset: csqa
# enc_name: roberta-large
# batch_size: 128
# learning_rate: elr 1e-5 dlr 1e-3
# gnn: dim 200 layer 5
# ******************************
# 2021-10-09 18:29:58.609333: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /user_data/.local/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# /user_data/.local/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:224: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   warnings.warn("To get the last learning rate computed by the scheduler, "
# 100%|������������������������������| 621/621 [01:36<00:00,  6.44it/s]
# 100%|������������������������������| 621/621 [01:35<00:00,  6.47it/s]
# 100%|������������������������������| 621/621 [01:35<00:00,  6.53it/s]
# 100%|������������������������������| 621/621 [01:36<00:00,  6.42it/s]
# Traceback (most recent call last):
#   File "qagnn.py", line 103, in main
#     train(args)
#   File "qagnn.py", line 258, in train
#     logits, _ = model(*[x[a:b] for x in input_data], layer_id=args.encoder_layer)
#   File "/user_data/.local/lib/python3.6/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/user_data/ZwZhang/qagnn/reference/modeling/modeling_qagnn.py", line 233, in forward
#     emb_data=None, cache_output=cache_output)
#   File "/user_data/.local/lib/python3.6/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/user_data/ZwZhang/qagnn/reference/modeling/modeling_qagnn.py", line 169, in forward
#     gnn_output = self.gnn(gnn_input, adj, node_type_ids, node_scores)
#   File "/user_data/.local/lib/python3.6/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/user_data/ZwZhang/qagnn/reference/modeling/modeling_qagnn.py", line 87, in forward
#     _X = self.mp_helper(_X, edge_index, edge_type, _node_type, _node_feature_extra)
#   File "/user_data/ZwZhang/qagnn/reference/modeling/modeling_qagnn.py", line 46, in mp_helper
#     _X = self.gnn_layers[_](_X, edge_index, edge_type, _node_type, _node_feature_extra)
#   File "/user_data/.local/lib/python3.6/site-packages/torch/nn/modules/module.py", line 532, in __call__
#     result = self.forward(*input, **kwargs)
#   File "/user_data/ZwZhang/qagnn/reference/modeling/modeling_qagnn.py", line 438, in forward
#     aggr_out = self.propagate(edge_index, x=x, edge_attr=edge_embeddings) #[N, emb_dim]
#   File "/user_data/.local/lib/python3.6/site-packages/torch_geometric/nn/conv/message_passing.py", line 236, in propagate
#     out = self.message(**msg_kwargs)
#   File "/user_data/ZwZhang/qagnn/reference/modeling/modeling_qagnn.py", line 461, in message
#     msg = self.linear_msg(torch.cat([x_j, edge_attr], dim=1)).view(-1, self.head_count, self.dim_per_head) #[E, heads, _dim]
# RuntimeError: CUDA out of memory. Tried to allocate 38.00 MiB (GPU 0; 10.91 GiB total capacity; 8.03 GiB already allocated; 8.38 MiB free; 8.34 GiB reserved in total by PyTorch)

# %%
print("end")
# Out:
# end
